# %% [markdown]
# # oops

# %%
# 1. What is Object-Oriented Programming (OOP)?
#    -Object-Oriented Programming (OOP) is a way of programming that organizes code into objects (data + actions) so it becomes easier to build, reuse, and manage.
#     Main Features of OOP
#     Example:
#      class Student:
#      def __init__(self, name):
#         self.name = name

#     def show(self):
#         print(self.name)

# s = Student("Ritika")
# s.show()

# 2.What is a class in OOP?
#   - A class is a blueprint or template used to create objects.
#     It defines properties (variables) and behaviors (methods) that the objects created from it will have.

# Class = Design/Blueprint
# Object = Actual item created from that design

# Example:
# class Student:
#     name = "Ritika"

# # create object
# s1 = Student()
# print(s1.name)


#3.What is an object in OOP?
# -An object is an instance of a class that contains its own data and can perform actions defined by the class.
# Example:
# class Car:
#     model = "Honda"

# car1 = Car()   # object
# print(car1.model)


#4.What is the difference between abstraction and encapsulation?
# -1. Abstraction

# Abstraction shows only essential details and hides unnecessary complexity from the user.

# Focus: What the object does.
# Example:class Car:
#     def start(self):
#         print("Car started")
    
# 2. Encapsulation

#   - Encapsulation bundles data and methods together and protects data using access controls.

# Focus: How data is protected.

# Example:class Person:
#     __age = 20      # private variable

#     def get_age(self):
#         return self.__age


#5.What are dunder methods in Python?
# - Dunder (Double-Underscore) methods are special predefined methods in Python that start and end with __.
# Example:
# class Student:
#     def __init__(self, name):   # dunder method
#         self.name = name

#     def __str__(self):          # dunder method
#         return self.name

# s1 = Student("Ritika")
# print(s1)   # calls __str__()


#6.Explain the concept of inheritance in OOP?
#  - Inheritance is an OOP concept where a new class (child) can use the properties and methods of an existing class (parent).

# It helps in:

# Reusability (no need to write code again)
# Extending features
# Organizing code
# Example:
# class Animal:        # Parent class
#     def sound(self):
#         print("Animal makes a sound")

# class Dog(Animal):   # Child class
#     def bark(self):
#         print("Dog barks")

# d = Dog()
# d.sound()   # inherited from Animal
# d.bark()    # own method


#7.What is polymorphism in OOP?
#  -Polymorphism means same method name, but different behavior depending on the object.
# Example:
# class Dog:
#     def sound(self):
#         print("Bark")
# class Cat:
#     def sound(self):
#         print("Meow")
# # same method name → different results
# for animal in (Dog(), Cat()):
#     animal.sound()


#8.How is encapsulation achieved in Python
#  - Encapsulation is achieved by restricting direct access to variables and methods using access modifiers.

# Python uses:

# Public (normal variables)
# Protected ( _var )
# Private ( __var )
# Example:
# class Person:
#     __age = 20     # private variable
#     def get_age(self):
#         return self.__age   # controlled access
# p = Person()
# print(p.get_age())


#9. What is a constructor in Python?
#   -A constructor is a special method in a class that runs automatically when an object is created.
# In Python, the constructor method is __init__().
# Example:
# class Student:
#     def __init__(self, name):
#         self.name = name   # initialized when object is created

# s1 = Student("Ritika")
# print(s1.name)


#10. What are class and static methods in Python?
#    - A class method works with the class itself, not with objects.
# It is defined using @classmethod and takes cls as the first parameter.
# Example:
# class Student:
#     count = 0

#     @classmethod
#     def show_count(cls):
#         print("Total students:", cls.count)


# #11.What is method overloading in Python?
#    -Method overloading refers to defining multiple methods with the same name but different parameter signatures.
# However, Python does not support traditional method overloading as seen in languages like Java or C++.
# Example:
#         class Calculator:
#     def add(self, *numbers):
#         return sum(numbers)

# calc = Calculator()
# print(calc.add(5, 10))        # behaves like 2-parameter method
# print(calc.add(1, 2, 3, 4))   # behaves like multi-parameter method


# #12.What is method overriding in OOP?
#    -Method overriding is an object-oriented programming mechanism in which a subclass redefines a method inherited from its superclass while preserving the same method signature (same name, parameters, and return type structure).
#     Example:
#             class Animal:
#     def sound(self):
#         print("Animal makes a sound")

# class Dog(Animal):
#     def sound(self):   # overriding
#         print("Dog barks")

# d = Dog()
# d.sound()


#13.What is a property decorator in Python?
#     -The @property decorator allows a method to be accessed like an attribute, enabling controlled and elegant access to class data while maintaining encapsulation.
#      Example:
#              class Person:
#     def __init__(self, age):
#         self._age = age

#     @property
#     def age(self):
#         return self._age

# p = Person(25)
# print(p.age)


#14.Why is polymorphism important in OOP?
#     - olymorphism is fundamental to OOP because it allows objects of different classes to be treated through a common interface, enabling dynamic method binding at runtime.
#       Example:
#               class Bird:
#     def sound(self):
#         print("Some sound")

# class Sparrow(Bird):
#     def sound(self):
#         print("Chirp")

# class Crow(Bird):
#     def sound(self):
#         print("Caw")

# for b in (Sparrow(), Crow()):
#     b.sound()


#15. What is an abstract class in Python?
#      - An abstract class is a class that cannot be directly created (instantiated) and is used as a blueprint for other classes.
#        Example:

# from abc import ABC, abstractmethod

# class Animal(ABC):
#     @abstractmethod
#     def sound(self):
#         pass
